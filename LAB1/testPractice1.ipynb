# %%
# !g++ Practice1.cpp -o practice1
# !echo "Test Case 1:"
# !echo 0 0 0 | ./practice1
# Out:
# Test Case 1:
#  Infinite solutions.

# %%
# !g++ Practice1.cpp -o practice1 
# !echo "Test Case 2:"
# !echo 0 0 1 | ./practice1
# Out:
# Test Case 2:
# No solution.

# %%
# !g++ Practice1.cpp -o practice1
# !echo "Test Case 3:"
# !echo 0 1 -4 | ./practice1
# Out:
# Test Case 3:
#  The equation has 2 real solution(s): 2 -2

# %%
# !g++ Practice1.cpp -o practice1
# !echo "Test Case 4:"
# !echo 1 -5 6 | ./practice1
# Out:
# Test Case 4:
#  The equation has 4 real solution(s): 1.73205 -1.73205 1.41421 -1.41421

# %%
# !g++ Practice1.cpp -o practice1
# !echo "Test Case 5:"
# !echo 1 2 1 | ./practice1
# Out:
# Test Case 5:
# No solution.

# %%
# !g++ Practice1.cpp -o practice1
# !echo "Test Case 6:"
# !echo 1 1 1 | ./practice1
# Out:
# Test Case 6:
# No solution.

# %%
# !g++ Practice1.cpp -o practice1
# !echo "Test Case 7:"
# !echo 1 0 -1 | ./practice1
# Out:
# Test Case 7:
#  The equation has 2 real solution(s): 1 -1

# %%
# !g++ Practice1.cpp -o practice1
# !echo "Test Case 8:"
# !echo 0 1 1 | ./practice1
# Out:
# Test Case 8:
# No solution.
