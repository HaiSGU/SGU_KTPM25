# %%
# !g++ baia.cpp -o baia
# !echo 11 | ./baia
# !echo 10 | ./baia
# Out:
# 22
# -10

# %%
# !g++ baib.cpp -o baib
# !echo 11 | ./baib
# !echo 9 | ./baib
# !echo -5 | ./baib
# Out:
# 22
# -9
# -10

# %%
# !g++ baic.cpp -o baic
# !echo 1 | ./baic
# !echo 5 | ./baic
# Out:
# 2
# 10

# %%
# !g++ baid.cpp -o baid
# !echo 2 | ./baid
# Out:
# 4

# %%
# !g++ baie.cpp -o baie
# !echo "5 3 2" | ./baie
# !echo "3 6 4" | ./baie
# !echo "8 8 8" | ./baie
# !echo "7 7 2" | ./baie
# Out:
# 5
# 6
# 0
# 0
